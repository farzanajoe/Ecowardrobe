# %%
import pandas as pd

# %%
print("This project will be amazing!")
# Out:
# This project will be amazing!

# %%
print("Testing: I also think This project will be amazing!")
# Out:
# Testing: I also think This project will be amazing!

# %%
print("Testing 2: #Cool")

# %%
print("hello world")
# Out:
# hello world
